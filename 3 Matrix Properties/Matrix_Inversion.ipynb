# %%
import numpy as np

# %%
#buat matrix X ukuran 2x2 menggunakan numpy
X = np.array([[108, 15], [-10, -10]])
X
# Out:
# array([[108,  15],
#        [-10, -10]])

# %%
#buat invers dari matrix X dan beri nama Xinv menggunakan numpy
Xinv = np.linalg.inv(X)
Xinv
# Out:
# array([[ 0.01075269,  0.01612903],
#        [-0.01075269, -0.11612903]])

# %%
#kalikan X dengan Xinv menggunakan numpy
np.dot(Xinv, X)
# Out:
# array([[1.00000000e+00, 2.77555756e-17],
#        [1.94289029e-16, 1.00000000e+00]])

# %% [markdown]
# selesaikan persamaan berikut menggunakan numpy, tensorflow dan pytorch
#
# ![image.png](data:image/png;base64,...)

# %%
y = np.array([4, -7])
y
# Out:
# array([ 4, -7])

# %%
w = np.dot(Xinv, y)
w
# Out:
# array([-0.06989247,  0.76989247])

# %%
np.dot(X, w)
# Out:
# array([ 4., -7.])

# %%
import torch
import tensorflow as tf

# %%
torch.inverse(torch.tensor([[4, 2], [-5, -3.]]))
# Out:
# tensor([[ 1.5000,  1.0000],
#         [-2.5000, -2.0000]])

# %%
tf.linalg.inv(tf.Variable([[4, 2], [-5, -3.]]))
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[ 1.4999998,  0.9999998],
#        [-2.4999995, -1.9999996]], dtype=float32)>

# %%
import numpy as np

# %%
#buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[45, 45], [45, 45], [45, 45]])
X
# Out:
# array([[45, 45],
#        [45, 45],
#        [45, 45]])

# %%
#tampilkan ukuran dari matrix X
X.shape
# Out:
# (3, 2)

# %%
X.size
# Out:
# 6

# %%
#tampilkan seluruh elemen dari kolom pertama dari matrix X
X[:,0]
# Out:
# array([45, 45, 45])

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X
X[0,:]
# Out:
# array([45, 45])

# %% [markdown]
# ulangi soal nomor 1 menggunakan pytorch

# %%
import torch

# %%
#buat matrix X_pt berukuran 2x3 menggunakan pytorch
X_pt = torch.tensor([[45, 45], [45, 45], [45, 45]])
X_pt
# Out:
# tensor([[45, 45],
#         [45, 45],
#         [45, 45]])

# %%
#tampilkan ukuran dari matrix X_pt
X_pt.shape
# Out:
# torch.Size([3, 2])

# %%
#tampilkan seluruh elemen dari kolom pertama dari matrix X_pt
X_pt[:,0]
# Out:
# tensor([45, 45, 45])

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X
X_pt[0,:]
# Out:
# tensor([45, 45])

# %% [markdown]
# ulangi soal nomor 1 menggunakan tensorflow

# %%
import tensorflow as tf

# %%
#buat matrix X_tf berukuran 2x3 menggunakan tensorflow
X_tf = tf.Variable([[45, 45], [45, 45], [45, 45]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[45, 45],
#        [45, 45],
#        [45, 45]], dtype=int32)>

# %%
#tampilkan ukuran dari matrix X_tf
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([3, 2], dtype=int32)>

# %%
#tampilkan seluruh elemen dari kolom pertama dari matrix X_tf
X_tf[:,0]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([45, 45, 45], dtype=int32)>

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X_tf
X_tf[0,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([45, 45], dtype=int32)>

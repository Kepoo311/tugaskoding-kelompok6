# %%
import numpy as np

# %% [markdown]
# lakukan perhitungan soal excercise menggunakan collab

# %%
import torch
M_q = torch.tensor([[10, 10, 10], [10, 10, 10], [10, 10, 10]])
M_q
# Out:
# tensor([[10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10]])

# %%
V_q = torch.tensor([[10, 10, 10], [10, 10, 10]]).T
V_q
# Out:
# tensor([[10, 10],
#         [10, 10],
#         [10, 10]])

# %%
torch.matmul(M_q, V_q)
# Out:
# tensor([[300, 300],
#         [300, 300],
#         [300, 300]])

# %%
#1 buat vector x dan y dengan ukuran 1x3 menggunakan numpy

# %%
import numpy as np

# %%
x = np.array([1,2,3])
x
# Out:
# array([1, 2, 3])

# %%
y = np.array([4,5,6])
y
# Out:
# array([[4, 5, 6]])

# %%
#buat vector x_pt dan y_pt dengan ukuran 1x3 menggunakan pytorch

# %%
import torch as pt

# %%
x_pt = pt.tensor([1,2,3])
x_pt
# Out:
# tensor([1, 2, 3])

# %%
y_pt = pt.tensor([4,5,6])
y_pt
# Out:
# tensor([4, 5, 6])

# %%
#buat vector x_tf dan y_tf dengan ukuran 1x3 menggunakan tensorflow

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable([1,2,3])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([1, 2, 3], dtype=int32)>

# %%
y_tf = tf.Variable([4,5,6])
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([4, 5, 6], dtype=int32)>

# %%
#2 hitung perkalian dot product antara vector x dan vector y

# %%
1*4 + 2*5 + 3*6
# Out:
# 32

# %%
np.dot(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8872/1184716858.py in <cell line: 0>()
# ----> 1 np.dot(x, y)
#
# ValueError: shapes (3,) and (2,2) not aligned: 3 (dim 0) != 2 (dim 0)

# %%
#hitung perkalian dot product antara vector x_pt dan vector y_pt

# %%
pt.dot(x_pt, y_pt)
# Out:
# tensor(32)

# %%
#hitung perkalian dot product antara vector x_tf dan vector y_tf

# %%
tf.reduce_sum(tf.multiply(x_tf, y_tf))
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=32>

# %%
#3 lakukan perhitungan excercise menggunakan collab

# %%
#what is y transpose?
y = np.array([[42,4,7,99],
              [-99,-3,17,22]
])
y_t = y.T
y_t
# Out:
# array([[ 42, -99],
#        [  4,  -3],
#        [  7,  17],
#        [ 99,  22]])

# %%
#what is the hadamasd product of these matrices?
a = np.array([[25,10],
              [-2,1]
])
b = np.array([[-1,7],
              [10,8]
])
(a*b)
# Out:
# array([[-25,  70],
#        [-20,   8]])

# %%
#what is the dot product of the tensor w and x?
w = np.array([-1,2,-2])
x = np.array([5,10,0])

np.dot(w, x)
# Out:
# np.int64(15)
